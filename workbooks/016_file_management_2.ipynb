# %%
import os
import sys
import pandas as pd

# %% [markdown]
# # File Management 2
#
# ## Pandas File Access
#
# We've already looked at our main tool for reading data from disk, the file read/write functionality in Pandas. When reading datasets this is normally all we need. Inside the read_csv function the Pandas people have either created all the file access stuff that they need to read a CSV or, more likely, they repurposed and extended some os library functions to do the work for them.

# %%
df = pd.read_csv("../data/chipotle.tsv", sep="\t")
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ## OS and File Read/Write
#
# We can also use the `os` module to do some basic file management. OS is a library that allows us to interact with the operating system on our local computer. Recall that our Python programs run inside an environment setup by the Python install on our computer. This means that as we work we are "inside" that separate environment and we can't directly interact with the underlying computer. The os library, and functions such as read_csv from other libraries, are a tool that allows us to bridge this gap. The os library that is presented to us gives us an assortment of commands to do things like delete files or change the directory we're using. The library's functions are then translated into the correct actions for the actual computer, and passed on to that computer, when the code is run in the Python environment. This also allows for Python code to be portable, or able to run with few to no changes, on different types of computers - I am using a Mac, most of you are probably using a PC, and we can also use a Unix/Linux based system like Google Colab. The code we write can work on all of those environments because of this abstraction, and in each case, the actions triggered by the os module will be different depending on the underlying operating system of the machine. In practice, many of the user-friendly libraries that we might use to access files or folders is built on top of the os module, so we often avoid needing to get into the weeds ourselves.
#
# We can use the `os` module to do things like:
# <ul>
#     <li>Get the current working directory</li>
#     <li>Change the current working directory</li>
#     <li>Get a list of files in a directory</li>
#     <li>Create a new directory</li>
#     <li>Remove a directory</li>
#     <li>Remove a file</li>
# </ul>
#
# First though, let's get some info about our system. Everyone will get totally different results here - I'm on a MacBook Air running MacOS, and I assume most of you have some variety of a PC running Windows. If you've ever seen any of those website things that tells you, "You are running Windows 10 in Edmonton, Ab..." this is a similar idea. The os.uname() function reaches out to the computer and retrieves some of it's identifying information for us.

# %%
for a in os.uname():
    print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for a in os.uname():
#       2     print(a)
#
# AttributeError: module 'os' has no attribute 'uname'

# %% [markdown]
# We can also get much more info by looking at the environment variables. These are variables that are set in the operating system and are available to any program running on the computer. These admittedly not frequently relevant to us doing some data science work, but it is a good example of connecting to the system. One thing that can matter to us is the PATH variable, which (roughly) lists all the places the system will look for programs to run. This is how the system knows where to find Python, for example - its in one of those places - as are all the programs installed on your machine.

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'AMDRMPATH': 'C:\\Program Files\\AMD\\RyzenMaster\\',
#         'APPDATA': 'C:\\Users\\Jacky Huynh\\AppData\\Roaming',
#         'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_18332_QHAZJAKSSTXLXTVN',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'JHUYNH',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONDA_ALLOW_SOFTLINKS': 'false',
#         'CONDA_DEFAULT_ENV': 'base',
#         'CONDA_EXE': 'C:\\Anaconda\\Scripts\\conda.exe',
#         'CONDA_PREFIX': 'C:\\Anaconda',
#         'CONDA_PROMPT_MODIFIER': '(base) ',
#         'CONDA_PYTHON_EXE': 'C:\\Anaconda\\python.exe',
#         'CONDA_ROOT': 'C:\\Anaconda',
#         'CONDA_SHLVL': '1',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\Jacky Huynh',
#         'JPY_INTERRUPT_EVENT': '2392',
#         'LOCALAPPDATA': 'C:\\Users\\Jacky Huynh\\AppData\\Local',
#         'LOGONSERVER': '\\\\JHUYNH',
#         'NUMBER_OF_PROCESSORS': '16',
#         'ONEDRIVE': 'C:\\Users\\Jacky Huynh\\OneDrive',
#         'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined',
#         'OS': 'Windows_NT',
#         'PATH': 'c:\\Anaconda;C:\\Anaconda;C:\\Anaconda\\Library\\mingw-w64\\bin;C:\\Anaconda\\Library\\usr\\bin;C:\\Anaconda\\Library\\bin;C:\\Anaconda\\Scripts;C:\\Anaconda\\bin;C:\\Anaconda\\condabin;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\Git\\cmd;C:\\Anaconda;C:\\Anaconda\\Scripts;C:\\Users\\Jacky Huynh\\AppData\\Local\\Programs\\Python\\Launcher;C:\\Users\\Jacky Huynh\\AppData\\Local\\Microsoft\\WindowsApps;E:\\yt-dlp;C:\\Users\\Jacky Huynh\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Anaconda\\Scripts;C:\\Anaconda;.;C:\\Users\\Jacky Huynh\\AppData\\Local\\Programs\\Azure Data Studio\\bin',
#         'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#         'PROCESSOR_ARCHITECTURE': 'AMD64',
#         'PROCESSOR_IDENTIFIER': 'AMD64 Family 25 Model 33 Stepping 2, AuthenticAMD',
#         'PROCESSOR_LEVEL': '25',
#         'PROCESSOR_REVISION': '2102',
#         'PROGRAMDATA': 'C:\\ProgramData',
#         'PROGRAMFILES': 'C:\\Program Files',
#         'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#         'PROGRAMW6432': 'C:\\Program Files',
#         'PROMPT': '(base) $P$G',
#         'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules',
#         'PUBLIC': 'C:\\Users\\Public',
#         'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#         'PYTHONIOENCODING': 'utf-8',
#         'PYTHONUNBUFFERED': '1',
#         'PYTHONUTF8': '1',
#         'PYTHON_FROZEN_MODULES': 'on',
#         'SESSIONNAME': 'Console',
#         'SSL_CERT_FILE': 'C:\\Anaconda\\Library\\ssl\\cacert.pem',
#         'SYSTEMDRIVE': 'C:',
#         'SYSTEMROOT': 'C:\\WINDOWS',
#         'TEMP': 'C:\\Users\\JACKYH~1\\AppData\\Local\\Temp',
#         'TMP': 'C:\\Users\\JACKYH~1\\AppData\\Local\\Temp',
#         'USERDOMAIN': 'JHUYNH',
#         'USERDOMAIN_ROAMINGPROFILE': 'JHUYNH',
#         'USERNAME': 'Jacky Huynh',
#         'USERPROFILE': 'C:\\Users\\Jacky Huynh',
#         'VBOX_HWVIRTEX_IGNORE_SVM_IN_USE': '1',
#         'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#         'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\Jacky Huynh\\AppData\\Roaming\\Code\\CachedData\\38c31bc77e0dd6ae88a4e9cc93428cc27a56ba40',
#         'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#         'VSCODE_CWD': 'C:\\Users\\Jacky Huynh\\AppData\\Local\\Programs\\Microsoft VS Code',
#         'VSCODE_DOTNET_INSTALL_TOOL_ORIGINAL_HOME': 'undefined',
#         'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#         'VSCODE_IPC_HOOK': '\\\\.\\pipe\\6fbd8c0f-1.93.1-main-sock',
#         'VSCODE_NLS_CONFIG': '{"userLocale":"en-us","osLocale":"en-us","resolvedLanguage":"en","defaultMessagesFile":"C:\\\\Users\\\\Jacky Huynh\\\\AppData\\\\Local\\\\Programs\\\\Microsoft VS Code\\\\resources\\\\app\\\\out\\\\nls.messages.json","locale":"en-us","availableLanguages":{}}',
#         'VSCODE_PID': '18332',
#         'WINDIR': 'C:\\WINDOWS',
#         '_CONDA_OLD_CHCP': '437',
#         '__CONDA_OPENSLL_CERT_FILE_SET': '"1"',
#         '__PSLOCKDOWNPOLICY': '0',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
os.environ["PATH"].split(":")
# Out:
# ['c',
#  '\\Anaconda;C',
#  '\\Anaconda;C',
#  '\\Anaconda\\Library\\mingw-w64\\bin;C',
#  '\\Anaconda\\Library\\usr\\bin;C',
#  '\\Anaconda\\Library\\bin;C',
#  '\\Anaconda\\Scripts;C',
#  '\\Anaconda\\bin;C',
#  '\\Anaconda\\condabin;C',
#  '\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C',
#  '\\WINDOWS\\system32;C',
#  '\\WINDOWS;C',
#  '\\WINDOWS\\System32\\Wbem;C',
#  '\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C',
#  '\\WINDOWS\\System32\\OpenSSH;C',
#  '\\Program Files\\Git\\cmd;C',
#  '\\Anaconda;C',
#  '\\Anaconda\\Scripts;C',
#  '\\Users\\Jacky Huynh\\AppData\\Local\\Programs\\Python\\Launcher;C',
#  '\\Users\\Jacky Huynh\\AppData\\Local\\Microsoft\\WindowsApps;E',
#  '\\yt-dlp;C',
#  '\\Users\\Jacky Huynh\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C',
#  '\\Anaconda\\Scripts;C',
#  '\\Anaconda;.;C',
#  '\\Users\\Jacky Huynh\\AppData\\Local\\Programs\\Azure Data Studio\\bin']

# %% [markdown]
# The shutil module is a partner to the os one, and provides some other functions. Among those, we can see disk usage.

# %%
import shutil
shutil.disk_usage("/")
# Out:
# usage(total=999133097984, used=293677322240, free=705455775744)

# %% [markdown]
# ## Folder Management
#
# The OS library also provides for an assortment of folder management functions. We can use these to create, rename, and delete folders.
#
# When using large datasets it is very common to have our data distributed over several folders. For example, if we are doing image recognition we might have a folder for "dogs", another with "cars", and another with "rutabagas". To construct our dataset we need to navigate over all of these folders and read in the files, using os and/or some similar libraries.
#
# Some common folder actions are:
# <ul>
# <li> os.mkdir() - create a new folder </li>
# <li> os.rename() - rename a folder </li>
# <li> os.rmdir() - remove a folder </li>
# <li> os.getcwd() - get the current working directory </li>
# <li> os.chdir() - change the current working directory </li>
# <li> os.listdir() - list the contents of a directory </li>
# </ul>

# %%
os.getcwd() # get current working directory
# Out:
# 'c:\\Users\\Jacky Huynh\\Desktop\\School - NAIT - 2024\\DATA3550 - Data Programming Fundamentals\\Workbook Repository\\Programming_Basics_for_Machine_Learning_Students\\workbooks'

# %% [markdown]
# <b>Note:</b> when using these functions, you need to be careful about where you are in the file system. In particular, the folder location doesn't reset itself automatically if you rerun everything. We need to restart the environment to reset the working directory, or navigate ourselves back to the correct location. The above command got the current working directory back from the Python environment, which in turn got it from the operating system. If we make a change to that directory, then rerun the above cell, we aren't "reset" to the original where we were when we started the program. To do that, we'd need to restart the environment, which would kill this current world in which our program is running, and generate a brand new one.
#
# Here I'm going to capture the current folder name and then move one level up, and back down.

# %%
org_fold = os.getcwd()
tmp = os.getcwd().split("/")[-1]
print(tmp)
os.chdir("../")
print(os.getcwd())
os.chdir(tmp)
print(os.getcwd())
# Out:
# c:\Users\Jacky Huynh\Desktop\School - NAIT - 2024\DATA3550 - Data Programming Fundamentals\Workbook Repository\Programming_Basics_for_Machine_Learning_Students\workbooks
# c:\Users\Jacky Huynh\Desktop\School - NAIT - 2024\DATA3550 - Data Programming Fundamentals\Workbook Repository\Programming_Basics_for_Machine_Learning_Students
# c:\Users\Jacky Huynh\Desktop\School - NAIT - 2024\DATA3550 - Data Programming Fundamentals\Workbook Repository\Programming_Basics_for_Machine_Learning_Students\workbooks

# %% [markdown]
# #### Handling File System Data
#
# We can also capture some of this information, and use it as a variable in our code that we can use to navigate the file system. For example, when grabbing the working directory above we stored it as a string and used the split command to break it into a hierarchy of folder names. Below we can pull the files in a folder and that data is returned in a list. If we have code where we need to jump around from folder to folder, we can use this list to help us navigate. For example, if we have a folder structure like this:
#
# ```
# data
#     - dogs
#         - dog1.jpg
#         - dog2.jpg
#         - dog3.jpg
#     - cats
#         - cat1.jpg
#         - cat2.jpg
#         - cat3.jpg
#     - rutabagas
#         - rutabaga1.jpg
#         - rutabaga2.jpg
#         - rutabaga3.jpg
# ```
# Our "base" folder is the data folder, and the subfolders inside are where we'll likely need to do all of our work. We can keep this map of the folder structure in some data structure, then we can use that info to move around. For example, we can find out where we are, visit each subfolder to do some work, and then move back to the base folder.

# %%
# Capture file list
# Print 5
#<b>Bonus:</b> at some point when we looked at strings, someone asked about putting a newline in an f string. I was wrong, it can work like this, no workarounds needed. 
file_list = os.listdir()
print(f"Number of flies: {len(file_list)}\n")
for file in range(5):
    print(file_list[file])
# Out:
# Number of flies: 72
#
# 000_Setup.ipynb
# 001a_python.py
# 001a_python_example.py
# 001_programming_basics.ipynb
# 001_programming_basics_sol.ipynb

# %% [markdown]
# ### Get Your Walk On
#
# ![Walk](../images/walk.gif "Walk")
#
# Manually navigating folder structures is pretty useful, but it also sucks and is error prone. The os.walk() function makes this a bit easier for us by doing the "walking" from one folder to another seamlessly.
#
# The os.walk() function returns a generator object, which is a special type of object that we can use to iterate over the contents of a folder. The generator object is a tuple, with the first element being the current folder, the second element being a list of subfolders, and the third element being a list of files. We can use this to iterate over the contents of a folder, and then iterate over the contents of each subfolder, and so on.
#
# The walk function returns a 3 part tuple for us:
# <ul>
#     <li> The current folder </li>
#     <li> A list of subfolders </li>
#     <li> A list of files </li>
# </ul>
#
# We can also use a flag to set if our walker will go top down or bottom up. The default is top down, which means we start at the top level folder and work our way down to the files. If we set the flag to False, we start at the bottom and work our way up. In practice, we pertty much always want top down - we have a folder inside our repository, such as "data" or "logs", and we want to navigate into it. Going the other direction moves "up" and if we leave our repository, that's the computer at large, and it could be anything. This may be useful if you're making an installed application, but most things that we're working on are contained to a specific location, so drilling down is normal.

# %%
# Iterator for file (grabs every single sub folder to iterate through)
walker = os.walk("../") # sub folder
moonwalker = os.walk("../", topdown=False) # parent folders

# %%
for root, directories, files, in walker:
    print(f"Root: {root}")
    print(f"Directories: {directories}")
    print(f"Files: {files}")
# Out:
# Root: ../
# Directories: ['.git', '.github', 'data', 'images', 'reference_material', 'supplementary_practice_workbooks', 'workbooks']
# Files: ['.gitignore', 'README.md']
# Root: ../.git
# Directories: ['hooks', 'info', 'logs', 'objects', 'refs']
# Files: ['config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD', 'packed-refs']
# Root: ../.git\hooks
# Directories: []
# Files: ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# Root: ../.git\info
# Directories: []
# Files: ['exclude']
# Root: ../.git\logs
# Directories: ['refs']
# Files: ['HEAD']
# Root: ../.git\logs\refs
# Directories: ['heads', 'remotes']
# Files: []
# Root: ../.git\logs\refs\heads
# Directories: []
# Files: ['main']
# Root: ../.git\logs\refs\remotes
# Directories: ['origin']
# Files: []
# Root: ../.git\logs\refs\remotes\origin
# Directories: []
# Files: ['HEAD', 'main']
# Root: ../.git\objects
# Directories: ['0a', '0b', '0d', '0f', '13', '16', '1c', '1d', '21', '2d', '2f', '32', '39', '40', '42', '44', '45', '49', '4c', '56', '60', '61', '63', '66', '6a', '6f', '74', '77', '78', '7e', '90', '92', '94', '97', '99', '9b', '9e', '9f', 'a4', 'a6', 'a7', 'aa', 'ac', 'b1', 'b6', 'b9', 'ba', 'bc', 'bf', 'c7', 'cb', 'ce', 'cf', 'd2', 'd3', 'd6', 'd9', 'e0', 'e2', 'e4', 'e9', 'ea', 'ee', 'f6', 'f9', 'fd', 'fe', 'ff', 'info', 'pack']
# Files: []
# Root: ../.git\objects\0a
# Directories: []
# Files: ['663c813dd6ace426ad2f28c0f412aa2ef8cf2d', 'a9fcbb0ff6e184028ce094843bfebc1c404eea']
# Root: ../.git\objects\0b
# Directories: []
# Files: ['5585bd89998b6e501c6b9056d5a500f456d3d4']
# Root: ../.git\objects\0d
# Directories: []
# Files: ['c80adf56277d95330cd8e6ae4503db00b08be5']
# Root: ../.git\objects\0f
# Directories: []
# Files: ['48f8a2e30811e85a00eb18a6cfe8947098bcaf']
# Root: ../.git\objects\13
# Directories: []
# Files: ['597d84f217d95d8d1ba0c2ede6df807370d03b']
# Root: ../.git\objects\16
# Directories: []
# Files: ['0e707ffe998b2176e0b879d320c7262fe786af', 'bfe1d394954e6ef50992b97c9663cd07112aa2']
# Root: ../.git\objects\1c
# Directories: []
# Files: ['a0c85a838cc288edff6b3abeaf32ba1429897e']
# Root: ../.git\objects\1d
# Directories: []
# Files: ['bc48834d92e93c3e70bb80e9eafb2fbe6a58a6']
# Root: ../.git\objects\21
# Directories: []
# Files: ['9033c44864192a2d7dd658d141f2b22a064ea4']
# Root: ../.git\objects\2d
# Directories: []
# Files: ['8c07bdeeda8c452fe2e9053eb181a3c15bc665']
# Root: ../.git\objects\2f
# Directories: []
# Files: ['0a27fb49e7fd0e6183f0b74601e38740fc7698']
# Root: ../.git\objects\32
# Directories: []
# Files: ['8e0089b13192a4f029f01e892fb0e0312cab77']
# Root: ../.git\objects\39
# Directories: []
# Files: ['ad69b5b29ee66289b5e1ce40b6e0f39fdb3555']
# Root: ../.git\objects\40
# Directories: []
# Files: ['4f1130fdd97d25e5ad6da9139a19a1a694a721']
# Root: ../.git\objects\42
# Directories: []
# Files: ['07249a6bcd5c99078518d2783d6877159edc78', '5ad7b4557b0a9f0d2c1971e057106da3c53108']
# Root: ../.git\objects\44
# Directories: []
# Files: ['7171061b65c56f6c655c0c4e9ce496bec28655']
# Root: ../.git\objects\45
# Directories: []
# Files: ['33842ddf7bb80d21d97d099b202fcf1a61fdaf']
# Root: ../.git\objects\49
# Directories: []
# Files: ['e59a2677f269e54515bab4c21608161c85b9da']
# Root: ../.git\objects\4c
# Directories: []
# Files: ['145eb25de66d6edf9e860cd2388f9d88c2518b']
# Root: ../.git\objects\56
# Directories: []
# Files: ['1ec27d3de36092b7a6d908ca0362804c8913dc', '65ca9402f817386a03a9d2f4eb3e941efd2463']
# Root: ../.git\objects\60
# Directories: []
# Files: ['a3f4cb5bf13dc8ead994a422970f067f43bff9']
# Root: ../.git\objects\61
# Directories: []
# Files: ['e659c266b2b319e7b1f899a99d2fb2ee6dcf86']
# Root: ../.git\objects\63
# Directories: []
# Files: ['1137d32b290046ddec53a2aced50678fc76158']
# Root: ../.git\objects\66
# Directories: []
# Files: ['17e7b52117117bbc13f926e0fab05650b091de']
# Root: ../.git\objects\6a
# Directories: []
# Files: ['59505a19225fda929aa133550cb19ba3042f83']
# Root: ../.git\objects\6f
# Directories: []
# Files: ['9c6c568895a22421a4c8a703d90bdbc7757ee7']
# Root: ../.git\objects\74
# Directories: []
# Files: ['3abaf7cd2c8a760e09d895d51e928cf6468b9f', '6f42deb7975fe9c3983d0e61a749bfd877ecf3']
# Root: ../.git\objects\77
# Directories: []
# Files: ['7337602b03806efcf584ffc65f37b1cabef998']
# Root: ../.git\objects\78
# Directories: []
# Files: ['2dac3f5b44089d9b801aa1d5f45a9594a71abd']
# Root: ../.git\objects\7e
# Directories: []
# Files: ['59d532c9961212e986a533b474b4e9e0f36c3b']
# Root: ../.git\objects\90
# Directories: []
# Files: ['c2ce8da27836f49e52f1cf78664ec7bf2b7de9']
# Root: ../.git\objects\92
# Directories: []
# Files: ['4b1b1fef07076d331c45e296b930fac32e0a2a']
# Root: ../.git\objects\94
# Directories: []
# Files: ['40305c3b3f3088890fa85973eb61e83256ac54']
# Root: ../.git\objects\97
# Directories: []
# Files: ['7393aa022ff28a4de284de187090fddea5772e']
# Root: ../.git\objects\99
# Directories: []
# Files: ['03b3befd85872c47c55b69dd4094776d64e3e4', 'eb4e894ccdfdd87ff6e749cde85510baf81544']
# Root: ../.git\objects\9b
# Directories: []
# Files: ['04d8eff15eb2085e1f5dae6f7ddce9ce84d3a4']
# Root: ../.git\objects\9e
# Directories: []
# Files: ['8857bc9fe3e17aa125b0da4f7dcfbc091824b7']
# Root: ../.git\objects\9f
# Directories: []
# Files: ['4c9c2990bba01e90e0ce76f82eef2e0e477975']
# Root: ../.git\objects\a4
# Directories: []
# Files: ['f9a59cceb21f0a1c389079650488086baa00bd']
# Root: ../.git\objects\a6
# Directories: []
# Files: ['03eadc2a126d4648ce825fae2fcf4ec0fcd7fa']
# Root: ../.git\objects\a7
# Directories: []
# Files: ['0814c2b1dc1a891be11398146e84c618854782']
# Root: ../.git\objects\aa
# Directories: []
# Files: ['9678946e81a8ed13425405651c14598c541d00']
# Root: ../.git\objects\ac
# Directories: []
# Files: ['f8d22a29885909ab06384e6f50a60903807f4a']
# Root: ../.git\objects\b1
# Directories: []
# Files: ['d5d678b40f9c7c9044c6ff43c8fec271b1e56c']
# Root: ../.git\objects\b6
# Directories: []
# Files: ['93641e6cf2d7f922e9863379d6ed65b25900cd']
# Root: ../.git\objects\b9
# Directories: []
# Files: ['2ef5d97a6e00bc95d7642b813ac70b0b2663a8']
# Root: ../.git\objects\ba
# Directories: []
# Files: ['1baca8597add89b0b54d94bd30d5d1b6cc3d8b']
# Root: ../.git\objects\bc
# Directories: []
# Files: ['c4da554dcb1ab3e695f5180528b5298736c491']
# Root: ../.git\objects\bf
# Directories: []
# Files: ['f3a29cefb5caff5cc2c95dcbebb8cfa526b06f']
# Root: ../.git\objects\c7
# Directories: []
# Files: ['911c52da0a9e755ced99f839610ca131513d15']
# Root: ../.git\objects\cb
# Directories: []
# Files: ['1ef55147456c7c72474a9b076855d9932f6ad2']
# Root: ../.git\objects\ce
# Directories: []
# Files: ['122ec02be28c9727bdd58ca7adf8f7ec6cfae8']
# Root: ../.git\objects\cf
# Directories: []
# Files: ['7725ed4aedef3410845f5b453d28ad5fa80fda']
# Root: ../.git\objects\d2
# Directories: []
# Files: ['824d12a09675af6026f8503b25b2cb880fe1e9']
# Root: ../.git\objects\d3
# Directories: []
# Files: ['7117b33cf9c9e993bd9b9c1e3c945b91452330']
# Root: ../.git\objects\d6
# Directories: []
# Files: ['4cb6e1052b104e434e6923c5a8889427797696']
# Root: ../.git\objects\d9
# Directories: []
# Files: ['fcd093a089fc9b129ac15f4f4889a39a40b584']
# Root: ../.git\objects\e0
# Directories: []
# Files: ['7230729076a92eb42b13ca092e05a5d48d94f4']
# Root: ../.git\objects\e2
# Directories: []
# Files: ['65b5e617263b96966bcdddc2caf24bd98f79ec', 'cba7198e0b6c271e7df763a46f52887d50867f']
# Root: ../.git\objects\e4
# Directories: []
# Files: ['bd0d8ba2727805853fd33f26422066770b5068']
# Root: ../.git\objects\e9
# Directories: []
# Files: ['e9f33f39af78ef48811de23c9595852a810775']
# Root: ../.git\objects\ea
# Directories: []
# Files: ['9be8bc32052758adcc4b836cddc9e0edf0bc1a']
# Root: ../.git\objects\ee
# Directories: []
# Files: ['daecd06f45558d77c7ba4662e2d030cdeaa48e']
# Root: ../.git\objects\f6
# Directories: []
# Files: ['ff64ba32b748574f99732cd1c10bbec469e5bd']
# Root: ../.git\objects\f9
# Directories: []
# Files: ['9077c8636c3e97aeda329eb25cea27d7aab12f', 'c327ae837883b5723298142a8b710b5e2499f1']
# Root: ../.git\objects\fd
# Directories: []
# Files: ['ed88dc9c5dc8b0b935d3162ab485ff10438b56']
# Root: ../.git\objects\fe
# Directories: []
# Files: ['3d67257ef3690cbd9c3dd42b232ab2fde94c18', 'bc5088346e1a5b6e850777317a1fdbd8ee509f']
# Root: ../.git\objects\ff
# Directories: []
# Files: ['38a7de80ef158ec3edd3c4d540b0e3b0ff8222']
# Root: ../.git\objects\info
# Directories: []
# Files: []
# Root: ../.git\objects\pack
# Directories: []
# Files: ['pack-4f8825a8ef7df2d4a4de66f70562de327973aefa.idx', 'pack-4f8825a8ef7df2d4a4de66f70562de327973aefa.pack', 'pack-4f8825a8ef7df2d4a4de66f70562de327973aefa.rev']
# Root: ../.git\refs
# Directories: ['heads', 'remotes', 'tags']
# Files: []
# Root: ../.git\refs\heads
# Directories: []
# Files: ['main']
# Root: ../.git\refs\remotes
# Directories: ['origin']
# Files: []
# Root: ../.git\refs\remotes\origin
# Directories: []
# Files: ['HEAD', 'main']
# Root: ../.git\refs\tags
# Directories: []
# Files: []
# Root: ../.github
# Directories: ['workflows']
# Files: []
# Root: ../.github\workflows
# Directories: []
# Files: ['blank.yml']
# Root: ../data
# Directories: []
# Files: ['03_city_edmonton_assessment_sample.csv', 'Car Electronics.csv', 'cars.csv', 'chipotle.tsv', 'HeightWeight.csv', 'Salary_Survey.csv', 'spam.csv', 'sportsref_download.xlsx', 'threads_reviews.csv', 'titanic_train.csv', 'train.csv']
# Root: ../images
# Directories: []
# Files: ['3d_array.webp', 'abc_collections.png', 'algorithm.jpg', 'arg_kwarg.png', 'array.png', 'array_calendar.png', 'array_memory.png', 'array_reshape.jpeg', 'binary_linear_search.gif', 'binary_vs_linear.jpg', 'df.webp', 'dict_list.jpg', 'dict_list.png', 'early_stopping.png', 'encapsulation.jpg', 'enumeration.png', 'example_dropdown.png', 'factorial.png', 'fact_breakdown.png', 'files_os.png', 'file_permissions.png', 'formatting.png', 'for_loop.jpg', 'for_loop.png', 'harvard_grades.webp', 'hash-table.png', 'hierarchial_inheritance.png', 'histogram.png', 'if_else.png', 'inheritance.png', 'inheritance_types.jpg', 'inh_types.webp', 'iterator.png', 'lambda.png', 'list_comprehension.png', 'logic-gates.webp', 'make_dict.jpg', 'map.png', 'map.webp', 'map_inputs.png', 'markdown.webp', 'marvin.png', 'multilevel_inheritance.png', 'multilevel_inheritance.webp', 'multiple_inh.png', 'nested_for.png', 'nested_if.png', 'new_method.png', 'numpy_indexing.png', 'pandas.png', 'paths.png', 'python-multiple-inheritance.png', 'python-sets.jpg', 'recursion.png', 'regex.png', 'regex_cheatsheet.webp', 'repr.png', 'seek.webp', 'series_dataframe.png', 'set_operations.png', 'sorting-algorithm.gif', 'sorting.png', 'string_index.png', 'stump.png', 'theon.jpeg', 'try_except.png', 'var_scope.webp', 'walk.gif', 'weak_learn.png', 'while_loop.png']
# Root: ../reference_material
# Directories: ['docs_and_guides', 'slides']
# Files: []
# Root: ../reference_material\docs_and_guides
# Directories: []
# Files: ['20_python_concepts.pdf', 'data_eng.pdf', 'Intro_to_Machine_Learning_in_Python.pdf', 'jupyter_markdown.pdf', 'large_python_cheat_sheet.pdf', 'pythonlearn.pdf', 'python_decorators.pdf', 'small_python_cheat_sheet.pdf', 'Super_Inherit.pdf']
# Root: ../reference_material\slides
# Directories: ['zz_OLD']
# Files: ['001_intro_setup.pptx', '002_vars_and_control.pptx', '003_loops.pptx', '004_functions.pptx', '005_file_access.pptx', '006_classes_obj_1.pptx', '007_other_data_structures.pptx', '008_recursion.pptx', '009_comments_enum.pptx', '012_algo_interface_errors.pptx', '013_arrays.pptx', '014_bulk_actions.pptx', '015_overload.pptx', '017_arg_kwarg.pptx', '018_cards_2.pptx', '019_test_driven.pptx', '020_regular_expressions.pptx', '021_review_verification.pptx', '022_mult_inh_abc.pptx', '023_asn2_work_time.pptx', '024_search_sort.pptx', '025_UI.pptx', '026_refactor.pptx', 'inheritance.pptx', 'os_system.pptx', '~$005_file_access.pptx']
# Root: ../reference_material\slides\zz_OLD
# Directories: ['Repository', 'Used']
# Files: []
# Root: ../reference_material\slides\zz_OLD\Repository
# Directories: []
# Files: ['002_Intro Machine Learning.pptx', '004_ml_basics.pptx', '006_Linear_Least_Squares.pptx', '008_Classification_Log_Reg.pptx', '008_Error_Bias_Variance.pptx', '010_log_reg_2_imbalanced.pptx', '012_Trees.pptx', '014_Forest_Ensamble.pptx', '016_Pipelines.pptx', '018_Gridsearch.pptx', 'Lecture01_Introduction.pptx', 'Lecture02_python_intro.pptx', 'Lecture03_datatypes.pptx', 'Lecture04_arrays_files.pptx', 'Lecture05_conditions_loops.pptx', 'Lecture06_numpy.pptx', 'Lecture07-08_Pandas.pptx', 'Lecture13_Intro_ML.pptx', 'Lecture14_ml_basics.pptx', 'Lecture15-16_Regression.pptx', 'Lecture16_LEAST_ ANGLE_REGRESSION.pdf', 'Lecture17-18_Classification.pptx', 'Lecture19_Pipelines.pptx', 'Lecture21-22_Para_Tuning.pptx', 'Lecture23-24_Classification_Tuning.ppt']
# Root: ../reference_material\slides\zz_OLD\Used
# Directories: []
# Files: ['002_vars_and_control.pptx', '003_loops.pptx', '004_functions.pptx', '005_Pandas_Datasheet.pptx', '006_Basic_Descriptive_Stats.pptx', '007_arrays.pptx', '008_review_1.pptx', '009_Correlation_Scatter.pptx', '010_Errors.pptx', '011_Linear_Least_Squares.pptx', '012_median_and_scaling.pptx', '013_categorical_features.pptx', '014_pipelines.pptx', '015_log_reg.pptx', '016_log_reg_2.pptx', '017_Gridsearch.pptx', '018_regression_review_stats.pptx', '019_Trees_over_under.pptx', '020_Trees_2_Regularization.pptx', '020_unsupervised_cluster.pptx', '021_Forest_Ensamble.pptx', '021_regression_tree.pptx', '022_Feature_Selection.pptx', '023_Basis_and_Regularization.pptx']
# Root: ../supplementary_practice_workbooks
# Directories: ['moodle_exercises']
# Files: ['data_dictionary.ipynb', 'Lecture02_basics.ipynb', 'Lecture02_workbook.ipynb', 'Lecture03_datatypes.ipynb', 'Lecture03_workbook.ipynb', 'Lecture04_arrays_files.ipynb', 'Lecture04_workbook.ipynb', 'Lecture05_conditions_loops.ipynb', 'Lecture05_workbook.ipynb', 'Lecture06_numpy.ipynb', 'Lecture06_workbook.ipynb', 'Lecture07-08_Pandas.ipynb', 'Lecture07-08_workbook.ipynb', 'Lecture09_data_wrangling_pandas_I.ipynb', 'Lecture10_data_wrangling_pandas_II.ipynb', 'Lecture11_12_Workbook.ipynb', 'Lecture11_descriptive_statistics.ipynb', 'Lecture12_probability.ipynb', 'Lecture13-14_Intro_ML.ipynb', 'Lecture13_workbook.ipynb', 'Lecture14_workbook.ipynb', 'Lecture15-16_workbook.ipynb', 'Lecture15_beginning_regression_part_1.ipynb', 'Lecture16_beginning_regression_part_2.ipynb', 'Lecture17_18_Workbook.ipynb', 'Lecture17_beginning_classification_part_1.ipynb', 'Lecture18_beginning_classification_part_2.ipynb', 'Lecture19_20_workbook.ipynb', 'Lecture19_pipeline_impute_part_1.ipynb', 'Lecture20_pipeline_part_2.ipynb', 'Lecture21_22_workbook.ipynb', 'Lecture21_Multiple_Regression.ipynb', 'Lecture22_Regression_Tuning.ipynb', 'Lecture23-24_classification_methods.ipynb', 'Lecture23_24_workbook.ipynb', 'Lecture_09_10_Workbook.ipynb']
# Root: ../supplementary_practice_workbooks\moodle_exercises
# Directories: []
# Files: ['10_Day_1_Object_Oriented_Programming.ipynb', '11_Inheritance_.ipynb', '1_exapmles.ipynb', '1_racing cars.ipynb', '2_Day_1.ipynb', '2_Examples.ipynb', '2_More Exercises.ipynb', '3 Day 1.ipynb', '4_Day_1.ipynb', '6 Day 1 - Lists and Functions.ipynb', '7_Day_1_Files_and_exceptions.ipynb', 'Week_9_Day_Sets_and_Dictionaries.ipynb']
# Root: ../workbooks
# Directories: ['development_working_dir', 'file_list', 'OLD', 'zz_OLD', '__pycache__']
# Files: ['000_Setup.ipynb', '001a_python.py', '001a_python_example.py', '001_programming_basics.ipynb', '001_programming_basics_sol.ipynb', '002_conditional_statements.ipynb', '002_conditional_statements_sol.ipynb', '003_loops.ipynb', '003_loops_sol.ipynb', '004_functions.ipynb', '004_functions_sol.ipynb', '005a_File_Loading_example_from_stats.ipynb', '005_file_access.ipynb', '005_file_access_sol.ipynb', '006_objects.ipynb', '006_objects_sol.ipynb', '007_other_data_structures.ipynb', '007_other_data_structures_full_sol.ipynb', '008_recursion.ipynb', '008_recursion_sol.ipynb', '009_strings.ipynb', '009_strings_sol.ipynb', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '011_looping_2_data_sol.ipynb', '012_algorithm_design.ipynb', '012_algorithm_design_sol.ipynb', '013_arrays_and_numpy.ipynb', '013_arrays_and_numpy_sol.ipynb', '014_map_apply.ipynb', '014_map_apply_sol.ipynb', '015_overloading.ipynb', '015_overloading_sol.ipynb', '016_file_management_2.ipynb', '016_file_management_2_sol.ipynb', '017a_cards.ipynb', '017a_cards_sol.ipynb', '017_args_kwargs.ipynb', '017_args_kwargs_sol.ipynb', '017_inheritance.ipynb', '017_inheritance_sol.ipynb', '018_cards_part_2.ipynb', '018_cards_part_2_akeem_in_class.ipynb', '018_cards_part_2_sol.ipynb', '019_cards_3_import.ipynb', '019_cards_3_import_sol.ipynb', '020_string_processing_regex.ipynb', '020_string_processing_regex_sol.ipynb', '021_big_review.ipynb', '022_abstract_multip_inh.ipynb', '022_abstract_multip_inh_sol.ipynb', '023_search_sort.ipynb', '023_search_sort_sol.ipynb', '024_cards_ipython.ipynb', '024_cards_ipython_sol.ipynb', '025_refactor_cards_gui.ipynb', '025_refactor_cards_gui_sol.ipynb', 'blah.ipynb', 'cards_sol.py', 'cards_sol_1.py', 'cards_sol_2.py', 'cards_sol_3.py', 'chipotle.tsv', 'fib.csv', 'file_list.zip', 'helper.py']
# Root: ../workbooks\development_working_dir
# Directories: ['file_list']
# Files: ['000_Setup.ipynb', '001a_python.py', '001_programming_basics.ipynb', '002_conditional_statements.ipynb', '003_loops.ipynb', '004_functions.ipynb', '005a_File_Loading_example_from_stats.ipynb', '005_file_access.ipynb', '006_objects.ipynb', '007_other_data_structures.ipynb', '008_recursion.ipynb', '009_strings_sol.ipynb', '010_class_comments.ipynb', '011_looping_2_data_sol.ipynb', '012_algorithm_design.ipynb', '013_arrays_and_numpy_sol.ipynb', '014_map_apply_sol.ipynb', '016_file_management_2_sol.ipynb', '017a_cards_sol.ipynb', '017_args_kwargs_sol.ipynb', '018_cards_part_2_sol.ipynb', '020_string_processing_regex_sol.ipynb', '021_big_review_sol.ipynb', '022_abstract_multip_inh_sol.ipynb', '023_functional.ipynb', '024_cards_ipython.ipynb', '025_refactor_cards_gui_sol.ipynb', 'abstract_class.ipynb', 'arrays_and_numpy_sol.ipynb', 'car.ipynb', 'cards_3_import_sol.ipynb', 'cards_sol.py', 'cards_sol_2.py', 'cards_sol_3.py', 'car_inh.py', 'Clothing.csv', 'Cycling.csv', 'date_data_sol.ipynb', 'difference.csv', 'diffs.csv', 'file_list.zip', 'helper.py', 'inheritance.ipynb', 'multip_inh.ipynb', 'overloading_sol.ipynb', 'poker_gui.ipynb', 'residential.csv', 'residential2.csv', 'run_from_command.py', 'search_sort.ipynb', 'Strength Training.csv', 'string_processing.ipynb', 'tmp.ipynb', 'z00_classes.ipynb']
# Root: ../workbooks\development_working_dir\file_list
# Directories: []
# Files: ['Clothing.csv']
# Root: ../workbooks\file_list
# Directories: []
# Files: ['001a_python_example.py', '002_conditional_statements_sol.ipynb', '005_file_access.ipynb', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '021_big_review.ipynb']
# Root: ../workbooks\OLD
# Directories: []
# Files: ['difference.csv', 'diffs.csv', 'fib.csv', 'file_list.zip']
# Root: ../workbooks\zz_OLD
# Directories: ['development_working_dir', 'file_list']
# Files: ['difference.csv', 'diffs.csv', 'fib.csv', 'file_list.zip']
# Root: ../workbooks\zz_OLD\development_working_dir
# Directories: ['file_list']
# Files: ['000_Setup.ipynb', '001a_python.py', '001_programming_basics.ipynb', '002_conditional_statements.ipynb', '003_loops.ipynb', '004_functions.ipynb', '005a_File_Loading_example_from_stats.ipynb', '005_file_access.ipynb', '006_objects.ipynb', '007_other_data_structures.ipynb', '008_recursion.ipynb', '009_strings_sol.ipynb', '010_class_comments.ipynb', '011_looping_2_data_sol.ipynb', '012_algorithm_design.ipynb', '013_arrays_and_numpy_sol.ipynb', '014_map_apply_sol.ipynb', '016_file_management_2_sol.ipynb', '017a_cards_sol.ipynb', '017_args_kwargs_sol.ipynb', '018_cards_part_2_sol.ipynb', '020_string_processing_regex_sol.ipynb', '021_big_review_sol.ipynb', '022_abstract_multip_inh_sol.ipynb', '023_functional.ipynb', '024_cards_ipython.ipynb', '025_refactor_cards_gui_sol.ipynb', 'abstract_class.ipynb', 'arrays_and_numpy_sol.ipynb', 'car.ipynb', 'cards_3_import_sol.ipynb', 'cards_sol.py', 'cards_sol_2.py', 'cards_sol_3.py', 'car_inh.py', 'Clothing.csv', 'Cycling.csv', 'date_data_sol.ipynb', 'difference.csv', 'diffs.csv', 'file_list.zip', 'helper.py', 'inheritance.ipynb', 'multip_inh.ipynb', 'overloading_sol.ipynb', 'poker_gui.ipynb', 'residential.csv', 'residential2.csv', 'run_from_command.py', 'search_sort.ipynb', 'Strength Training.csv', 'string_processing.ipynb', 'tmp.ipynb', 'z00_classes.ipynb']
# Root: ../workbooks\zz_OLD\development_working_dir\file_list
# Directories: []
# Files: ['Clothing.csv']
# Root: ../workbooks\zz_OLD\file_list
# Directories: []
# Files: ['001a_python_example.py', '002_conditional_statements_sol.ipynb', '005_file_access.ipynb', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '021_big_review.ipynb']
# Root: ../workbooks\__pycache__
# Directories: []
# Files: ['helper.cpython-312.pyc']

# %%
for root, directories, files, in moonwalker:
    print(f"Root: {root}")
    print(f"Directories: {directories}")
    print(f"Files: {files}")
# Out:
# Root: ../.git\hooks
# Directories: []
# Files: ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# Root: ../.git\info
# Directories: []
# Files: ['exclude']
# Root: ../.git\logs\refs\heads
# Directories: []
# Files: ['main']
# Root: ../.git\logs\refs\remotes\origin
# Directories: []
# Files: ['HEAD', 'main']
# Root: ../.git\logs\refs\remotes
# Directories: ['origin']
# Files: []
# Root: ../.git\logs\refs
# Directories: ['heads', 'remotes']
# Files: []
# Root: ../.git\logs
# Directories: ['refs']
# Files: ['HEAD']
# Root: ../.git\objects\0a
# Directories: []
# Files: ['663c813dd6ace426ad2f28c0f412aa2ef8cf2d', 'a9fcbb0ff6e184028ce094843bfebc1c404eea']
# Root: ../.git\objects\0b
# Directories: []
# Files: ['5585bd89998b6e501c6b9056d5a500f456d3d4']
# Root: ../.git\objects\0d
# Directories: []
# Files: ['c80adf56277d95330cd8e6ae4503db00b08be5']
# Root: ../.git\objects\0f
# Directories: []
# Files: ['48f8a2e30811e85a00eb18a6cfe8947098bcaf']
# Root: ../.git\objects\13
# Directories: []
# Files: ['597d84f217d95d8d1ba0c2ede6df807370d03b']
# Root: ../.git\objects\16
# Directories: []
# Files: ['0e707ffe998b2176e0b879d320c7262fe786af', 'bfe1d394954e6ef50992b97c9663cd07112aa2']
# Root: ../.git\objects\1c
# Directories: []
# Files: ['a0c85a838cc288edff6b3abeaf32ba1429897e']
# Root: ../.git\objects\1d
# Directories: []
# Files: ['bc48834d92e93c3e70bb80e9eafb2fbe6a58a6']
# Root: ../.git\objects\21
# Directories: []
# Files: ['9033c44864192a2d7dd658d141f2b22a064ea4']
# Root: ../.git\objects\2d
# Directories: []
# Files: ['8c07bdeeda8c452fe2e9053eb181a3c15bc665']
# Root: ../.git\objects\2f
# Directories: []
# Files: ['0a27fb49e7fd0e6183f0b74601e38740fc7698']
# Root: ../.git\objects\32
# Directories: []
# Files: ['8e0089b13192a4f029f01e892fb0e0312cab77']
# Root: ../.git\objects\39
# Directories: []
# Files: ['ad69b5b29ee66289b5e1ce40b6e0f39fdb3555']
# Root: ../.git\objects\40
# Directories: []
# Files: ['4f1130fdd97d25e5ad6da9139a19a1a694a721']
# Root: ../.git\objects\42
# Directories: []
# Files: ['07249a6bcd5c99078518d2783d6877159edc78', '5ad7b4557b0a9f0d2c1971e057106da3c53108']
# Root: ../.git\objects\44
# Directories: []
# Files: ['7171061b65c56f6c655c0c4e9ce496bec28655']
# Root: ../.git\objects\45
# Directories: []
# Files: ['33842ddf7bb80d21d97d099b202fcf1a61fdaf']
# Root: ../.git\objects\49
# Directories: []
# Files: ['e59a2677f269e54515bab4c21608161c85b9da']
# Root: ../.git\objects\4c
# Directories: []
# Files: ['145eb25de66d6edf9e860cd2388f9d88c2518b']
# Root: ../.git\objects\56
# Directories: []
# Files: ['1ec27d3de36092b7a6d908ca0362804c8913dc', '65ca9402f817386a03a9d2f4eb3e941efd2463']
# Root: ../.git\objects\60
# Directories: []
# Files: ['a3f4cb5bf13dc8ead994a422970f067f43bff9']
# Root: ../.git\objects\61
# Directories: []
# Files: ['e659c266b2b319e7b1f899a99d2fb2ee6dcf86']
# Root: ../.git\objects\63
# Directories: []
# Files: ['1137d32b290046ddec53a2aced50678fc76158']
# Root: ../.git\objects\66
# Directories: []
# Files: ['17e7b52117117bbc13f926e0fab05650b091de']
# Root: ../.git\objects\6a
# Directories: []
# Files: ['59505a19225fda929aa133550cb19ba3042f83']
# Root: ../.git\objects\6f
# Directories: []
# Files: ['9c6c568895a22421a4c8a703d90bdbc7757ee7']
# Root: ../.git\objects\74
# Directories: []
# Files: ['3abaf7cd2c8a760e09d895d51e928cf6468b9f', '6f42deb7975fe9c3983d0e61a749bfd877ecf3']
# Root: ../.git\objects\77
# Directories: []
# Files: ['7337602b03806efcf584ffc65f37b1cabef998']
# Root: ../.git\objects\78
# Directories: []
# Files: ['2dac3f5b44089d9b801aa1d5f45a9594a71abd']
# Root: ../.git\objects\7e
# Directories: []
# Files: ['59d532c9961212e986a533b474b4e9e0f36c3b']
# Root: ../.git\objects\90
# Directories: []
# Files: ['c2ce8da27836f49e52f1cf78664ec7bf2b7de9']
# Root: ../.git\objects\92
# Directories: []
# Files: ['4b1b1fef07076d331c45e296b930fac32e0a2a']
# Root: ../.git\objects\94
# Directories: []
# Files: ['40305c3b3f3088890fa85973eb61e83256ac54']
# Root: ../.git\objects\97
# Directories: []
# Files: ['7393aa022ff28a4de284de187090fddea5772e']
# Root: ../.git\objects\99
# Directories: []
# Files: ['03b3befd85872c47c55b69dd4094776d64e3e4', 'eb4e894ccdfdd87ff6e749cde85510baf81544']
# Root: ../.git\objects\9b
# Directories: []
# Files: ['04d8eff15eb2085e1f5dae6f7ddce9ce84d3a4']
# Root: ../.git\objects\9e
# Directories: []
# Files: ['8857bc9fe3e17aa125b0da4f7dcfbc091824b7']
# Root: ../.git\objects\9f
# Directories: []
# Files: ['4c9c2990bba01e90e0ce76f82eef2e0e477975']
# Root: ../.git\objects\a4
# Directories: []
# Files: ['f9a59cceb21f0a1c389079650488086baa00bd']
# Root: ../.git\objects\a6
# Directories: []
# Files: ['03eadc2a126d4648ce825fae2fcf4ec0fcd7fa']
# Root: ../.git\objects\a7
# Directories: []
# Files: ['0814c2b1dc1a891be11398146e84c618854782']
# Root: ../.git\objects\aa
# Directories: []
# Files: ['9678946e81a8ed13425405651c14598c541d00']
# Root: ../.git\objects\ac
# Directories: []
# Files: ['f8d22a29885909ab06384e6f50a60903807f4a']
# Root: ../.git\objects\b1
# Directories: []
# Files: ['d5d678b40f9c7c9044c6ff43c8fec271b1e56c']
# Root: ../.git\objects\b6
# Directories: []
# Files: ['93641e6cf2d7f922e9863379d6ed65b25900cd']
# Root: ../.git\objects\b9
# Directories: []
# Files: ['2ef5d97a6e00bc95d7642b813ac70b0b2663a8']
# Root: ../.git\objects\ba
# Directories: []
# Files: ['1baca8597add89b0b54d94bd30d5d1b6cc3d8b']
# Root: ../.git\objects\bc
# Directories: []
# Files: ['c4da554dcb1ab3e695f5180528b5298736c491']
# Root: ../.git\objects\bf
# Directories: []
# Files: ['f3a29cefb5caff5cc2c95dcbebb8cfa526b06f']
# Root: ../.git\objects\c7
# Directories: []
# Files: ['911c52da0a9e755ced99f839610ca131513d15']
# Root: ../.git\objects\cb
# Directories: []
# Files: ['1ef55147456c7c72474a9b076855d9932f6ad2']
# Root: ../.git\objects\ce
# Directories: []
# Files: ['122ec02be28c9727bdd58ca7adf8f7ec6cfae8']
# Root: ../.git\objects\cf
# Directories: []
# Files: ['7725ed4aedef3410845f5b453d28ad5fa80fda']
# Root: ../.git\objects\d2
# Directories: []
# Files: ['824d12a09675af6026f8503b25b2cb880fe1e9']
# Root: ../.git\objects\d3
# Directories: []
# Files: ['7117b33cf9c9e993bd9b9c1e3c945b91452330']
# Root: ../.git\objects\d6
# Directories: []
# Files: ['4cb6e1052b104e434e6923c5a8889427797696']
# Root: ../.git\objects\d9
# Directories: []
# Files: ['fcd093a089fc9b129ac15f4f4889a39a40b584']
# Root: ../.git\objects\e0
# Directories: []
# Files: ['7230729076a92eb42b13ca092e05a5d48d94f4']
# Root: ../.git\objects\e2
# Directories: []
# Files: ['65b5e617263b96966bcdddc2caf24bd98f79ec', 'cba7198e0b6c271e7df763a46f52887d50867f']
# Root: ../.git\objects\e4
# Directories: []
# Files: ['bd0d8ba2727805853fd33f26422066770b5068']
# Root: ../.git\objects\e9
# Directories: []
# Files: ['e9f33f39af78ef48811de23c9595852a810775']
# Root: ../.git\objects\ea
# Directories: []
# Files: ['9be8bc32052758adcc4b836cddc9e0edf0bc1a']
# Root: ../.git\objects\ee
# Directories: []
# Files: ['daecd06f45558d77c7ba4662e2d030cdeaa48e']
# Root: ../.git\objects\f6
# Directories: []
# Files: ['ff64ba32b748574f99732cd1c10bbec469e5bd']
# Root: ../.git\objects\f9
# Directories: []
# Files: ['9077c8636c3e97aeda329eb25cea27d7aab12f', 'c327ae837883b5723298142a8b710b5e2499f1']
# Root: ../.git\objects\fd
# Directories: []
# Files: ['ed88dc9c5dc8b0b935d3162ab485ff10438b56']
# Root: ../.git\objects\fe
# Directories: []
# Files: ['3d67257ef3690cbd9c3dd42b232ab2fde94c18', 'bc5088346e1a5b6e850777317a1fdbd8ee509f']
# Root: ../.git\objects\ff
# Directories: []
# Files: ['38a7de80ef158ec3edd3c4d540b0e3b0ff8222']
# Root: ../.git\objects\info
# Directories: []
# Files: []
# Root: ../.git\objects\pack
# Directories: []
# Files: ['pack-4f8825a8ef7df2d4a4de66f70562de327973aefa.idx', 'pack-4f8825a8ef7df2d4a4de66f70562de327973aefa.pack', 'pack-4f8825a8ef7df2d4a4de66f70562de327973aefa.rev']
# Root: ../.git\objects
# Directories: ['0a', '0b', '0d', '0f', '13', '16', '1c', '1d', '21', '2d', '2f', '32', '39', '40', '42', '44', '45', '49', '4c', '56', '60', '61', '63', '66', '6a', '6f', '74', '77', '78', '7e', '90', '92', '94', '97', '99', '9b', '9e', '9f', 'a4', 'a6', 'a7', 'aa', 'ac', 'b1', 'b6', 'b9', 'ba', 'bc', 'bf', 'c7', 'cb', 'ce', 'cf', 'd2', 'd3', 'd6', 'd9', 'e0', 'e2', 'e4', 'e9', 'ea', 'ee', 'f6', 'f9', 'fd', 'fe', 'ff', 'info', 'pack']
# Files: []
# Root: ../.git\refs\heads
# Directories: []
# Files: ['main']
# Root: ../.git\refs\remotes\origin
# Directories: []
# Files: ['HEAD', 'main']
# Root: ../.git\refs\remotes
# Directories: ['origin']
# Files: []
# Root: ../.git\refs\tags
# Directories: []
# Files: []
# Root: ../.git\refs
# Directories: ['heads', 'remotes', 'tags']
# Files: []
# Root: ../.git
# Directories: ['hooks', 'info', 'logs', 'objects', 'refs']
# Files: ['config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD', 'packed-refs']
# Root: ../.github\workflows
# Directories: []
# Files: ['blank.yml']
# Root: ../.github
# Directories: ['workflows']
# Files: []
# Root: ../data
# Directories: []
# Files: ['03_city_edmonton_assessment_sample.csv', 'Car Electronics.csv', 'cars.csv', 'chipotle.tsv', 'HeightWeight.csv', 'Salary_Survey.csv', 'spam.csv', 'sportsref_download.xlsx', 'threads_reviews.csv', 'titanic_train.csv', 'train.csv']
# Root: ../images
# Directories: []
# Files: ['3d_array.webp', 'abc_collections.png', 'algorithm.jpg', 'arg_kwarg.png', 'array.png', 'array_calendar.png', 'array_memory.png', 'array_reshape.jpeg', 'binary_linear_search.gif', 'binary_vs_linear.jpg', 'df.webp', 'dict_list.jpg', 'dict_list.png', 'early_stopping.png', 'encapsulation.jpg', 'enumeration.png', 'example_dropdown.png', 'factorial.png', 'fact_breakdown.png', 'files_os.png', 'file_permissions.png', 'formatting.png', 'for_loop.jpg', 'for_loop.png', 'harvard_grades.webp', 'hash-table.png', 'hierarchial_inheritance.png', 'histogram.png', 'if_else.png', 'inheritance.png', 'inheritance_types.jpg', 'inh_types.webp', 'iterator.png', 'lambda.png', 'list_comprehension.png', 'logic-gates.webp', 'make_dict.jpg', 'map.png', 'map.webp', 'map_inputs.png', 'markdown.webp', 'marvin.png', 'multilevel_inheritance.png', 'multilevel_inheritance.webp', 'multiple_inh.png', 'nested_for.png', 'nested_if.png', 'new_method.png', 'numpy_indexing.png', 'pandas.png', 'paths.png', 'python-multiple-inheritance.png', 'python-sets.jpg', 'recursion.png', 'regex.png', 'regex_cheatsheet.webp', 'repr.png', 'seek.webp', 'series_dataframe.png', 'set_operations.png', 'sorting-algorithm.gif', 'sorting.png', 'string_index.png', 'stump.png', 'theon.jpeg', 'try_except.png', 'var_scope.webp', 'walk.gif', 'weak_learn.png', 'while_loop.png']
# Root: ../reference_material\docs_and_guides
# Directories: []
# Files: ['20_python_concepts.pdf', 'data_eng.pdf', 'Intro_to_Machine_Learning_in_Python.pdf', 'jupyter_markdown.pdf', 'large_python_cheat_sheet.pdf', 'pythonlearn.pdf', 'python_decorators.pdf', 'small_python_cheat_sheet.pdf', 'Super_Inherit.pdf']
# Root: ../reference_material\slides\zz_OLD\Repository
# Directories: []
# Files: ['002_Intro Machine Learning.pptx', '004_ml_basics.pptx', '006_Linear_Least_Squares.pptx', '008_Classification_Log_Reg.pptx', '008_Error_Bias_Variance.pptx', '010_log_reg_2_imbalanced.pptx', '012_Trees.pptx', '014_Forest_Ensamble.pptx', '016_Pipelines.pptx', '018_Gridsearch.pptx', 'Lecture01_Introduction.pptx', 'Lecture02_python_intro.pptx', 'Lecture03_datatypes.pptx', 'Lecture04_arrays_files.pptx', 'Lecture05_conditions_loops.pptx', 'Lecture06_numpy.pptx', 'Lecture07-08_Pandas.pptx', 'Lecture13_Intro_ML.pptx', 'Lecture14_ml_basics.pptx', 'Lecture15-16_Regression.pptx', 'Lecture16_LEAST_ ANGLE_REGRESSION.pdf', 'Lecture17-18_Classification.pptx', 'Lecture19_Pipelines.pptx', 'Lecture21-22_Para_Tuning.pptx', 'Lecture23-24_Classification_Tuning.ppt']
# Root: ../reference_material\slides\zz_OLD\Used
# Directories: []
# Files: ['002_vars_and_control.pptx', '003_loops.pptx', '004_functions.pptx', '005_Pandas_Datasheet.pptx', '006_Basic_Descriptive_Stats.pptx', '007_arrays.pptx', '008_review_1.pptx', '009_Correlation_Scatter.pptx', '010_Errors.pptx', '011_Linear_Least_Squares.pptx', '012_median_and_scaling.pptx', '013_categorical_features.pptx', '014_pipelines.pptx', '015_log_reg.pptx', '016_log_reg_2.pptx', '017_Gridsearch.pptx', '018_regression_review_stats.pptx', '019_Trees_over_under.pptx', '020_Trees_2_Regularization.pptx', '020_unsupervised_cluster.pptx', '021_Forest_Ensamble.pptx', '021_regression_tree.pptx', '022_Feature_Selection.pptx', '023_Basis_and_Regularization.pptx']
# Root: ../reference_material\slides\zz_OLD
# Directories: ['Repository', 'Used']
# Files: []
# Root: ../reference_material\slides
# Directories: ['zz_OLD']
# Files: ['001_intro_setup.pptx', '002_vars_and_control.pptx', '003_loops.pptx', '004_functions.pptx', '005_file_access.pptx', '006_classes_obj_1.pptx', '007_other_data_structures.pptx', '008_recursion.pptx', '009_comments_enum.pptx', '012_algo_interface_errors.pptx', '013_arrays.pptx', '014_bulk_actions.pptx', '015_overload.pptx', '017_arg_kwarg.pptx', '018_cards_2.pptx', '019_test_driven.pptx', '020_regular_expressions.pptx', '021_review_verification.pptx', '022_mult_inh_abc.pptx', '023_asn2_work_time.pptx', '024_search_sort.pptx', '025_UI.pptx', '026_refactor.pptx', 'inheritance.pptx', 'os_system.pptx', '~$005_file_access.pptx']
# Root: ../reference_material
# Directories: ['docs_and_guides', 'slides']
# Files: []
# Root: ../supplementary_practice_workbooks\moodle_exercises
# Directories: []
# Files: ['10_Day_1_Object_Oriented_Programming.ipynb', '11_Inheritance_.ipynb', '1_exapmles.ipynb', '1_racing cars.ipynb', '2_Day_1.ipynb', '2_Examples.ipynb', '2_More Exercises.ipynb', '3 Day 1.ipynb', '4_Day_1.ipynb', '6 Day 1 - Lists and Functions.ipynb', '7_Day_1_Files_and_exceptions.ipynb', 'Week_9_Day_Sets_and_Dictionaries.ipynb']
# Root: ../supplementary_practice_workbooks
# Directories: ['moodle_exercises']
# Files: ['data_dictionary.ipynb', 'Lecture02_basics.ipynb', 'Lecture02_workbook.ipynb', 'Lecture03_datatypes.ipynb', 'Lecture03_workbook.ipynb', 'Lecture04_arrays_files.ipynb', 'Lecture04_workbook.ipynb', 'Lecture05_conditions_loops.ipynb', 'Lecture05_workbook.ipynb', 'Lecture06_numpy.ipynb', 'Lecture06_workbook.ipynb', 'Lecture07-08_Pandas.ipynb', 'Lecture07-08_workbook.ipynb', 'Lecture09_data_wrangling_pandas_I.ipynb', 'Lecture10_data_wrangling_pandas_II.ipynb', 'Lecture11_12_Workbook.ipynb', 'Lecture11_descriptive_statistics.ipynb', 'Lecture12_probability.ipynb', 'Lecture13-14_Intro_ML.ipynb', 'Lecture13_workbook.ipynb', 'Lecture14_workbook.ipynb', 'Lecture15-16_workbook.ipynb', 'Lecture15_beginning_regression_part_1.ipynb', 'Lecture16_beginning_regression_part_2.ipynb', 'Lecture17_18_Workbook.ipynb', 'Lecture17_beginning_classification_part_1.ipynb', 'Lecture18_beginning_classification_part_2.ipynb', 'Lecture19_20_workbook.ipynb', 'Lecture19_pipeline_impute_part_1.ipynb', 'Lecture20_pipeline_part_2.ipynb', 'Lecture21_22_workbook.ipynb', 'Lecture21_Multiple_Regression.ipynb', 'Lecture22_Regression_Tuning.ipynb', 'Lecture23-24_classification_methods.ipynb', 'Lecture23_24_workbook.ipynb', 'Lecture_09_10_Workbook.ipynb']
# Root: ../workbooks\development_working_dir\file_list
# Directories: []
# Files: ['Clothing.csv']
# Root: ../workbooks\development_working_dir
# Directories: ['file_list']
# Files: ['000_Setup.ipynb', '001a_python.py', '001_programming_basics.ipynb', '002_conditional_statements.ipynb', '003_loops.ipynb', '004_functions.ipynb', '005a_File_Loading_example_from_stats.ipynb', '005_file_access.ipynb', '006_objects.ipynb', '007_other_data_structures.ipynb', '008_recursion.ipynb', '009_strings_sol.ipynb', '010_class_comments.ipynb', '011_looping_2_data_sol.ipynb', '012_algorithm_design.ipynb', '013_arrays_and_numpy_sol.ipynb', '014_map_apply_sol.ipynb', '016_file_management_2_sol.ipynb', '017a_cards_sol.ipynb', '017_args_kwargs_sol.ipynb', '018_cards_part_2_sol.ipynb', '020_string_processing_regex_sol.ipynb', '021_big_review_sol.ipynb', '022_abstract_multip_inh_sol.ipynb', '023_functional.ipynb', '024_cards_ipython.ipynb', '025_refactor_cards_gui_sol.ipynb', 'abstract_class.ipynb', 'arrays_and_numpy_sol.ipynb', 'car.ipynb', 'cards_3_import_sol.ipynb', 'cards_sol.py', 'cards_sol_2.py', 'cards_sol_3.py', 'car_inh.py', 'Clothing.csv', 'Cycling.csv', 'date_data_sol.ipynb', 'difference.csv', 'diffs.csv', 'file_list.zip', 'helper.py', 'inheritance.ipynb', 'multip_inh.ipynb', 'overloading_sol.ipynb', 'poker_gui.ipynb', 'residential.csv', 'residential2.csv', 'run_from_command.py', 'search_sort.ipynb', 'Strength Training.csv', 'string_processing.ipynb', 'tmp.ipynb', 'z00_classes.ipynb']
# Root: ../workbooks\file_list
# Directories: []
# Files: ['001a_python_example.py', '002_conditional_statements_sol.ipynb', '005_file_access.ipynb', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '021_big_review.ipynb']
# Root: ../workbooks\OLD
# Directories: []
# Files: ['difference.csv', 'diffs.csv', 'fib.csv', 'file_list.zip']
# Root: ../workbooks\zz_OLD\development_working_dir\file_list
# Directories: []
# Files: ['Clothing.csv']
# Root: ../workbooks\zz_OLD\development_working_dir
# Directories: ['file_list']
# Files: ['000_Setup.ipynb', '001a_python.py', '001_programming_basics.ipynb', '002_conditional_statements.ipynb', '003_loops.ipynb', '004_functions.ipynb', '005a_File_Loading_example_from_stats.ipynb', '005_file_access.ipynb', '006_objects.ipynb', '007_other_data_structures.ipynb', '008_recursion.ipynb', '009_strings_sol.ipynb', '010_class_comments.ipynb', '011_looping_2_data_sol.ipynb', '012_algorithm_design.ipynb', '013_arrays_and_numpy_sol.ipynb', '014_map_apply_sol.ipynb', '016_file_management_2_sol.ipynb', '017a_cards_sol.ipynb', '017_args_kwargs_sol.ipynb', '018_cards_part_2_sol.ipynb', '020_string_processing_regex_sol.ipynb', '021_big_review_sol.ipynb', '022_abstract_multip_inh_sol.ipynb', '023_functional.ipynb', '024_cards_ipython.ipynb', '025_refactor_cards_gui_sol.ipynb', 'abstract_class.ipynb', 'arrays_and_numpy_sol.ipynb', 'car.ipynb', 'cards_3_import_sol.ipynb', 'cards_sol.py', 'cards_sol_2.py', 'cards_sol_3.py', 'car_inh.py', 'Clothing.csv', 'Cycling.csv', 'date_data_sol.ipynb', 'difference.csv', 'diffs.csv', 'file_list.zip', 'helper.py', 'inheritance.ipynb', 'multip_inh.ipynb', 'overloading_sol.ipynb', 'poker_gui.ipynb', 'residential.csv', 'residential2.csv', 'run_from_command.py', 'search_sort.ipynb', 'Strength Training.csv', 'string_processing.ipynb', 'tmp.ipynb', 'z00_classes.ipynb']
# Root: ../workbooks\zz_OLD\file_list
# Directories: []
# Files: ['001a_python_example.py', '002_conditional_statements_sol.ipynb', '005_file_access.ipynb', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '021_big_review.ipynb']
# Root: ../workbooks\zz_OLD
# Directories: ['development_working_dir', 'file_list']
# Files: ['difference.csv', 'diffs.csv', 'fib.csv', 'file_list.zip']
# Root: ../workbooks\__pycache__
# Directories: []
# Files: ['helper.cpython-312.pyc']
# Root: ../workbooks
# Directories: ['development_working_dir', 'file_list', 'OLD', 'zz_OLD', '__pycache__']
# Files: ['000_Setup.ipynb', '001a_python.py', '001a_python_example.py', '001_programming_basics.ipynb', '001_programming_basics_sol.ipynb', '002_conditional_statements.ipynb', '002_conditional_statements_sol.ipynb', '003_loops.ipynb', '003_loops_sol.ipynb', '004_functions.ipynb', '004_functions_sol.ipynb', '005a_File_Loading_example_from_stats.ipynb', '005_file_access.ipynb', '005_file_access_sol.ipynb', '006_objects.ipynb', '006_objects_sol.ipynb', '007_other_data_structures.ipynb', '007_other_data_structures_full_sol.ipynb', '008_recursion.ipynb', '008_recursion_sol.ipynb', '009_strings.ipynb', '009_strings_sol.ipynb', '010_class_comments.ipynb', '011_looping_2_data.ipynb', '011_looping_2_data_sol.ipynb', '012_algorithm_design.ipynb', '012_algorithm_design_sol.ipynb', '013_arrays_and_numpy.ipynb', '013_arrays_and_numpy_sol.ipynb', '014_map_apply.ipynb', '014_map_apply_sol.ipynb', '015_overloading.ipynb', '015_overloading_sol.ipynb', '016_file_management_2.ipynb', '016_file_management_2_sol.ipynb', '017a_cards.ipynb', '017a_cards_sol.ipynb', '017_args_kwargs.ipynb', '017_args_kwargs_sol.ipynb', '017_inheritance.ipynb', '017_inheritance_sol.ipynb', '018_cards_part_2.ipynb', '018_cards_part_2_akeem_in_class.ipynb', '018_cards_part_2_sol.ipynb', '019_cards_3_import.ipynb', '019_cards_3_import_sol.ipynb', '020_string_processing_regex.ipynb', '020_string_processing_regex_sol.ipynb', '021_big_review.ipynb', '022_abstract_multip_inh.ipynb', '022_abstract_multip_inh_sol.ipynb', '023_search_sort.ipynb', '023_search_sort_sol.ipynb', '024_cards_ipython.ipynb', '024_cards_ipython_sol.ipynb', '025_refactor_cards_gui.ipynb', '025_refactor_cards_gui_sol.ipynb', 'blah.ipynb', 'cards_sol.py', 'cards_sol_1.py', 'cards_sol_2.py', 'cards_sol_3.py', 'chipotle.tsv', 'fib.csv', 'file_list.zip', 'helper.py']
# Root: ../
# Directories: ['.git', '.github', 'data', 'images', 'reference_material', 'supplementary_practice_workbooks', 'workbooks']
# Files: ['.gitignore', 'README.md']

# %% [markdown]
# ## Exercise
#
# Attempt to list the folders and files in the level above where this notebook is located. Create a list of folders and a list of files. Return them in a tuple.

# %%
# def genList(path="../"):
#     foldersList = []
#     filesList = []
#     for root, directories, files in os.walk(path):
#         foldersList.append(directories)
#         filesList.append(files)
#     return (foldersList, filesList)

def genList(path="../"):
    foldersList = []
    filesList = []
    for item in os.listdir(path): # listdir only returns as string, so this cannot check if 'item' is a directory or file
        if os.path.isdir(path + item):
            print(f"Folder: {item}")
            foldersList.append(item)
        else:
            print(f"File: {item}")
            filesList.append(item)
    return (foldersList,filesList)

# %%
genList()[0]
# Out:
# Folder: .git
# Folder: .github
# File: .gitignore
# Folder: data
# Folder: images
# File: README.md
# Folder: reference_material
# Folder: supplementary_practice_workbooks
# Folder: workbooks
# ['.git',
#  '.github',
#  'data',
#  'images',
#  'reference_material',
#  'supplementary_practice_workbooks',
#  'workbooks']

# %%
genList()[1]
# Out:
# Folder: .git
# .git
# Folder: .github
# .github
# File: .gitignore
# Folder: data
# data
# Folder: images
# images
# File: README.md
# Folder: reference_material
# reference_material
# Folder: supplementary_practice_workbooks
# supplementary_practice_workbooks
# Folder: workbooks
# workbooks
# ['.gitignore', 'README.md']

# %% [markdown]
# #### Exists
#
# We can also check if a file or folder exists. This is useful if we're going to be creating a new file or folder, and we want to make sure we don't overwrite something that already exists.

# %%
print(os.path.exists("chipotle.tsv"))
print(os.path.exists("mad_bitcoin_keys.tsv"))

# %% [markdown]
# ### File Paths
#
# When navigating file systems we necessarily need to deal with file paths, or the locations in the file structure where each file is located. There are two types of file paths, absolute and relative.
#
# ![Paths](../images/paths.png "Paths")
#
# #### Absolute Paths
#
# An absolute path is the full path to a file or folder. It starts at the root of the file system and lists each folder in the hierarchy, separated by a slash. For example, on my Mac, the root of the file system is "/". If I want to get to my home folder, I need to go to "/Users/". If I want to get to my Documents folder, I need to go to "/Users/akeem/Documents". If I want to get to my "downloads" folder, I need to go to "/Users/akeem/Downloads".
#
# Absolute file paths will rarely be relevant for us, it is relevant if you are writing lower level programs, that deal more directly with a file system. Note that different operating systems have different file systems, so the absolute path on a Mac is different than the absolute path on a PC - you can't rely on any particular configuration.
#
# <b>Note:</b> those environment variables that we mentioned above are some of the things that tell programs where to look for stuff, they indicate the root directories of things like the user's home folder, or the location of the program files.
#
# #### Relative Paths
#
# Relative paths are relative to the current working directory. If I am in the root directory of this repository, the relative path to each workbook is workbooks\workbook_name.ipynb. If I am in the workbooks folder, the relative path to each workbook is just the name of the workbook. If I am in the data folder, the relative path to each workbook is ../workbooks/workbook_name.ipynb.
#
# When working within a repository we use relative paths to refer to other files. This allows us to pass around the repository, or move it to a different machine, and things still work. For example, all the data and image references in these workbooks uses a relative path, so it works just fine on my Mac and your different computers without any issue. One important value when using relative paths is ../ which means "go up one level", so if we are in the "workbooks" folder here, we can use ../ to get to the root of the repository.
#
# ### Joining Paths
#
# When we need to deal with file paths we can use the os.path.join() function to join together the parts of the path. This is useful because it will automatically handle the differences between operating systems for us. For example, on a Mac the path separator is "/", while on a PC it is "\". The os.path.join() function will automatically use the correct separator for the operating system we are using.
#
# For example, to get the absolute path to a file, we can use the os.path.join() function to join together the current working directory and the relative path to the file.

# %%
file_name = "016_file_management_2.ipynb"
fold_path = os.getcwd()
print(f"File path: {os.path.join(fold_path, file_name)}")

# %% [markdown]
# ## Reading and Writing Text Files
#
# Now that we have an idea what is in our folders, we can start recklessly changing things. For example, we can use the os write functions to make a new CSV file and write some data to it. One thing that is reveled to us here that might not be visible is you're used to Windows machines is a look at what is a "text" file. Text files are .txt, but also .csv, .tsv, .py, etc... meaning all of these types of files is made up of just plain text, and we can edit them in any text editor on a computer - the file extension doesn't dictate it, that's for our convenience. The structure of our code will:
# <ul>
# <li> Open a connection to the file, if it doesn't exist this will create it. </li>
# <li> Perform the contents of the loop - writing some data to a file for 100 lines. </li>
# <li> When that writing task is complete, it will close the connection automatically thanks to the with. </li>
# </ul>
#
# In the open() function call to connect to the file we provide the second argument that defines what type of access we get to the file we are opening:
# <ul>
# <b><li> 'r' - read only </li>
# <li> 'w' - write only </li>
# <li> 'a' - append to the end of the file </li>
# <li> 'r+' - read and write </li></b>
# <li> 'w+' - write and read, overwrites existing files</li>
# </ul>
#
# These are mostly pretty simple and self-explanatory, with the exception of the distinction between r+ and w. The 'r+' option is a bit more complicated. This will open the file for reading and writing, but it will not create the file if it doesn't exist. If you try to open a file that doesn't exist with 'r+' you will get an error. The `w` option will create the file if it doesn't exist, but it will also overwrite the file if it does exist. So if we are making something brand new, we want `w`, but if we are attempting to update an existing file, we want `r+`. This is an easy place to make an error, so we should be careful. We can also check to see if the file we want to make already exists, then make a decision. `W+` is another weird option, it is read/write, but will overwrite the file if it exists.
#
# ![File Permissions](../../images/file_permissions.png "File Permissions" )
# ![File Permissions](../images/file_permissions.png "File Permissions" )
#
# Choosing the level of access of a file that we open is important in terms of writing our code to prevent errors. We want to open the file with the least impactful level of access that we need to have to do what we want. So if we are just reading data from a file, opening it as read only will prevent us accidentally changing that file in any way, as we don't even have the ability to do so. If we want a brand-new file, opening it as write only will prevent any old data that may have been hanging around from persisting. The more flexible the level of access, the more options we have for what we can do, the more likely it is that we may do something unintentional.
#
# <b>Note:</b> this will go to our current directory, wherever the pointer is, so if you got rid of that line to reset the locations, it would spit this file out to whatever folder you happen to be in.

# %% [markdown]
# #### Create a CSV with Fibonacci Numbers
#
# Here we'll make a CSV, fib.csv, that has two coulmns - an index and the fibonacci number at that index.

# %%
# write fibonacci series to a file
end_fib = 30

def fib(n):
    if n < 2:
        return n
    else:
        return fib(n-2) + fib(n-1)

with open("fib.csv", "w") as f:
    f.write("Index,Fibonacci Series\n")
    i = 0
    while i < end_fib:
        f.write(f"{i},{fib(i)}\n")
        #print(f"{i},{fib(i)}")
        i += 1
print("Done")
# Out:
# Done

# %% [markdown]
# #### Reading Our File
#
# Now that our file is written, we can read it and see what we got. We need to specify the `r` here, since we are only reading. When reading from a file, there's a few main options:
# <ul>
# <li> read() - read the entire file into a single string </li>
# <li> readline() - read the file one line at a time </li>
# <li> readlines() - read the file into a list of strings, one per line </li>
# </ul>
#
# The first, read, takes in the entire file into one string. This is fine for small files, but for things that are large it is unruly. For most things of size we probably want to navigate the file one line at a time, using the readline() option. There's also a common shortcut that we can do with a for loop that does this for us easily:
#
#     ``` for line in file: ```
#
# If we are reading in a large file, one line at a time is a better choice. Depending on what we are doing, we may be able to process our data and "deal with it" - whether that be saving it to another file or loading it into some dataset - on the fly. When we get to neural networks towards the end of machine learning, we'll try to read enough data so that our processor is busy - so the computer is never waiting for either data or a free processor. Loading batches allows us to make the most of the power of our computer, as we can minimize the amount of time any part of it spends waiting for something else to finish.

# %%
with open("fib.csv", "r") as f:
   for line in f:
      print(line)
# Out:
# Index,Fibonacci Series
#
# 0,0
#
# 1,1
#
# 2,1
#
# 3,2
#
# 4,3
#
# 5,5
#
# 6,8
#
# 7,13
#
# 8,21
#
# 9,34
#
# 10,55
#
# 11,89
#
# 12,144
#
# 13,233
#
# 14,377
#
# 15,610
#
# 16,987
#
# 17,1597
#
# 18,2584
#
# 19,4181
#
# 20,6765
#
# 21,10946
#
# 22,17711
#
# 23,28657
#
# 24,46368
#
# 25,75025
#
# 26,121393
#
# 27,196418
#
# 28,317811
#
# 29,514229
# 55

# %%
with open("fib.csv", "r") as f:
    fib_list = f.readlines()
print(fib_list)
# Out:
# ['Index,Fibonacci Series\n', '0,0\n', '1,1\n', '2,1\n', '3,2\n', '4,3\n', '5,5\n', '6,8\n', '7,13\n', '8,21\n', '9,34\n', '10,55\n', '11,89\n', '12,144\n', '13,233\n', '14,377\n', '15,610\n', '16,987\n', '17,1597\n', '18,2584\n', '19,4181\n', '20,6765\n', '21,10946\n', '22,17711\n', '23,28657\n', '24,46368\n', '25,75025\n', '26,121393\n', '27,196418\n', '28,317811\n', '29,514229\n']

# %% [markdown]
# We can also read it into a CSV, for fun!

# %%
df2 = pd.read_csv("fib.csv", index_col=None)
df2.head()
# Out:
#    Index  Fibonacci Series
# 0      0                 0
# 1      1                 1
# 2      2                 1
# 3      3                 2
# 4      4                 3

# %% [markdown]
# #### Seek
#
# When in a file, we can use the seek() function to move around. This is useful if we want to go back to the beginning of the file, or jump to a specific location. The seek() function takes in two arguments, the first is the location we want to go to, and the second is the reference point. The reference point can be 0, 1, or 2.
# <ul>
# <li>0 is the beginning of the file</li>
# <li>1 is the current location</li>
# <li>2 is the end of the file</li>
# </ul>
#
# So if we want to go to the beginning of the file, we can use seek(0,0). If we want to go to the end of the file, we can use seek(0,2). If we want to go to the 100th character in the file, we can use seek(100,0). If we want to go to the 100th character from the end of the file, we can use seek(-100,2).
#
# Note that in the examples below I've changed a couple of things - the open uses "rb" or "read binary" instead of "r" or "read". This is to allow us to do the offsets from the end or the current position - the system needs to deal with the binary file. Second, I've added that decode statement to the print statement. This is because the file is binary, so we need to decode it to get it into a string that we can print nicely. Note the last one - I didn't change the encoding. Text encoding is something we need to deal with, but something that is minor - we basically need to make sure that we are using the encoding that matches the file, or we need to re-encode it.
#
# #### Tell
#
# We can also use the tell() function to find out where we are in the file. This is useful if we want to jump around, but we don't know where we are. We can use tell() to find out where we are, then use seek() to go somewhere else.
#
# <b>Note:</b> the readline calls advance the pointer, so each readline is moving us ahead in the file from where the seek() command dropped us off.

# %%
# Open fib and seek/tell
with open("fib.csv", "rb") as f:
    print("At the stat of the file:")
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At position 150:")
    f.seek(150, 0)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At position 20, relative to the current position:")
    f.seek(20, os.SEEK_CUR)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At position 5:")
    f.seek(5, 0)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("At the end:")
    f.seek(0, os.SEEK_END)
    print("Position", f.tell())
    print(f.readline().decode("utf-8"))

    print("Moving back from the end:")
    f.seek(-5, 2)
    print("Position", f.tell())
    print(f.readline())
# Out:
# At the stat of the file:
# Position 0
# Index,Fibonacci Series
#
# At position 150:
# Position 150
# 9,4181
#
# At position 20, relative to the current position:
# SEEK_CUR 158
# Position 178
# 2,17711
#
# At position 5:
# Position 5
# ,Fibonacci Series
#
# At the end:
# Position 261
#
# Moving back from the end:
# Position 256
# b'229\r\n'

# %% [markdown]
# #### Appending a File and the In-File Pointer
#
# Another of the options above that is a little odd is the `a`, for append. This will open the file and add new data to the end of it, but it will not overwrite the existing data. This is useful if we want to add new data to an existing file, but we don't want to lose the old data. This is very useful for things like logs - we likely have a pretty substantial amount of data accumulated in a big text file and we want to add new stuff without losing the old data or having to deal with the old data at all. We can use this to basically tack some entries onto the end of a file easily.
#
# This issue of opening an existing file normally vs appending seems pretty minor, but it can have larger performance implications than we might expect. For example, server logs can be many, many GB of text that lists errors or warnings going back years. We want to keep the log, and we also want to add today's entries. Opening a 2GB file "normally", navigating to the end, then spitting it back out can be slow, appending directly to the end of that same file is fast. This is because just like navigating a file system, a text file itself has a pointer that maintains your position - think of it as an invisible cursor just like we have in any program where we type. Append puts that position cursor directly at the end, and just starts writing. Personally, I once had a job where I remade a little program that went to approximately 150 servers, grabbed their log file, and looked for last night's entry at the end of the file to see if a backup failed. By changing it from opening the files normally, to appending (roughly, the language wasn't Python), I cut the runtime from 4 to 5 hours to about <10 minutes - without making any actual improvements to the logic of the code, just by jumping directly to the end of the text. When someone wrote the original, all the log files were probably tiny, as the system was new, so it didn't matter for performance; as things grew, this became an issue.
#
# <b>Note:</b> the "it's slow to open a large file and write to the end" thing is obviously a common issue for computers in general. File access packages know this, and are built to be fast no matter what. This idea is still true, just less true than it is with older software.

# %%
with open("fib.csv", "a") as f:
    print(f.tell())
# Out:
# 261

# %% [markdown]
# ## Exercise
#
# Complete the spotReader function to take in a file and a spot in that file, and return that line.

# %%
def spotReader(filepath, spot):
    with open(filepath, 'r') as f:
        f.seek(spot, 0) # start from beginning, move forward to spot
        return f.readline()

# %%
spotReader("fib.csv", 150)
# Out:
# '9,4181\n'

# %% [markdown]
# ### Remote Data
#
# We can also use some code to programmatically download data from the internet. This can save us from having to download large files, but it can also help us to build automated pipelines for getting data.
#
# One thing that I've worked on a lot in industry is importing data from other systems into LMS systems like Moodle. A common process to do this is for the other system to export a CSV file to a specific location on a file server, then a script that we created will grab the new file from the pre-defined location and feed it into our import work. Applications for personal use are also broad - we could automate downloads of files that are regularly updated.
#
# For pretty much any data source that we might want to be able to access, there is likely a library that will do so. So we can access FTP servers, different file share protocols, and so on - we just need to look up the correct tool for whichever data source we want to access.
#
# <b>Note:</b> there are many libraries that download files, they're pretty much interchangeable. I'm using `urllib.request` here because it's built into Python and is the "basic standard", but you could also use `requests` or `wget` or `curl` or any number of other libraries. For this, and the others, look at the documentation to see the options and how to use the functions - they are generally similar to this, just provide a URL and a destination.

# %%
# Download
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
import urllib.request
try:
    urllib.request.urlretrieve(url, 'chipotle.tsv')
except:
    print("Error downloading file")

# %% [markdown]
# ### Compression
#
# Many files that we deal with, particularly when downloading datasets, may be compressed. Several libraries provide tools for us to programmatically deal with these files, including decompressing them and moving their files into our working directory.
#
# <b>Note:</b> Pandas read_csv function can also read compressed files directly, so you can load my_data.zip or similar with no interim decompression step.

# %%
# Compress some files
import zipfile

# Zip first 5 files in file_list
with zipfile.ZipFile('file_list.zip', 'w') as myzip:
    for file in range(5):
        myzip.write(file_list[file])

# %% [markdown]
# Decompress into a folder

# %%
# Decompress file_list.zip into file_list folder
with zipfile.ZipFile('file_list.zip', 'r') as myzip:
    myzip.extractall('file_list')

# %% [markdown]
# ## Exercise
#
# Create the function ipynb crawler. When given a directory, assemble and return a list of all .ipynb files in that directory and all subdirectories.

# %%
def ipynbCrawler(directory_targ="../"):
   ipynbFiles = []
   subDirectories = []

   for item in os.listdir(directory_targ):
      if os.path.isdir(directory_targ + item):
         subDirectories.append(item)
      elif item.endswith('.ipynb'):
         ipynbFiles.append(item)
      # else:
      #    print(item)
   return ipynbFiles, subDirectories

# %%
ipynbCrawler()
# Out:
# (['README - Copy.ipynb'],
#  ['.git',
#   '.github',
#   'data',
#   'images',
#   'reference_material',
#   'supplementary_practice_workbooks',
#   'workbooks'])
